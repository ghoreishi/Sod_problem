n_2= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**2_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20_skipConnectionep=0.1.txt")
n_2_5= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**2.5_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20_skipConnectionep=0.1.txt")
n_3 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**3_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20_skipConnectionep=0.1.txt")
n_4= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20_skip_conection.txt")

axs[0].plot(x, n_2[19900:20000,0], linewidth=2.0)
axs[0].plot(x, n_2_5[19900:20000,0], linewidth=2.0)
axs[0].plot(x, n_3[19900:20000,0], linewidth=2.0)
axs[0].plot(x, n_4[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["n = 2","n = 2.5", "n = 3", "n = 4", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, n_2[19900:20000,1], linewidth=2.0)
axs[1].plot(x, n_2_5[19900:20000,1], linewidth=2.0)
axs[1].plot(x, n_3[19900:20000,1], linewidth=2.0)
axs[1].plot(x, n_4[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["n = 2","n = 2.5", "n = 3", "n = 4", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, n_2[19900:20000,2], linewidth=2.0)
axs[2].plot(x, n_2_5[19900:20000,2], linewidth=2.0)
axs[2].plot(x, n_3[19900:20000,2], linewidth=2.0)
axs[2].plot(x, n_4[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["n = 2","n = 2.5", "n = 3", "n = 4", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
####### continuity and energy without coefficient ###########
####### power of momentum coefficient = 2.5 ##########
####### compare skip connection ###########
######## W2 = 0.1 ########

fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1),sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

n_2_5= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**2.5_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20ep=0.1.txt")
n_2_5_withSkipConnection = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withoutLanda/comparePower_CoefMomentum/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**2.5_continuty_and_energy=withoutLanda_LBFGS=2000_layers=12_Neurons=20_skipConnectionep=0.1.txt")

axs[0].plot(x, n_2_5[19900:20000,0], linewidth=2.0)
axs[0].plot(x, n_2_5_withSkipConnection[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["Without Skip Connection","With Skip Connection", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, n_2_5[19900:20000,1], linewidth=2.0)
axs[1].plot(x, n_2_5_withSkipConnection[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["Without Skip Connection","With Skip Connection", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, n_2_5[19900:20000,2], linewidth=2.0)
axs[2].plot(x, n_2_5_withSkipConnection[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["Without Skip Connection","With Skip Connection", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
######## W2 = 1 ########

# %%
####### continuity and energy Eq. with Landa_u n=1 , ep=0.001 ###########
####### Momentum coefficient n=4 , ep2=0.001 ##########
####### with skip connection ###########
######## Compare Adam ########
######## W2 = 1 ########


fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1),sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

Adam_5000= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareAdam/result_Tanh_sobol_float64_Adam=5000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")
Adam_8000= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareAdam/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")
Adam_12000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareAdam/result_Tanh_sobol_float64_Adam=12000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")
Adam_20000= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareAdam/result_Tanh_sobol_float64_Adam=20000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")

axs[0].plot(x, Adam_5000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, Adam_8000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, Adam_12000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, Adam_20000[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["Adam = 5000","Adam = 8000", "Adam = 12000", "Adam = 20000", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, Adam_5000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, Adam_8000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, Adam_12000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, Adam_20000[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["Adam = 5000","Adam = 8000", "Adam = 12000", "Adam = 20000", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, Adam_5000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, Adam_8000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, Adam_12000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, Adam_20000[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["Adam = 5000","Adam = 8000", "Adam = 12000", "Adam = 20000", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
####### continuity and energy Eq. with Landa_u n=1 , ep=0.001 ###########
####### Momentum coefficient n=4 , ep2=0.001 ##########
####### with skip connection ###########
######## Compare LBFGS ########
######## W2 = 1 ########

fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1),sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

LBFGS_2000= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareLBFGS/result_Tanh_sobol_float64_Adam=12000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")
LBFGS_4000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=1/CompareLBFGS/result_Tanh_sobol_float64_Adam=12000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=4000_layers=12_Neurons=20_skipConnection_w2=1_ep=0.001.txt")

axs[0].plot(x, LBFGS_2000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, LBFGS_4000[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["LBFGS = 2000","LBFGS = 4000", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, LBFGS_2000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, LBFGS_4000[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["LBFGS = 2000","LBFGS = 4000", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, LBFGS_2000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, LBFGS_4000[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["LBFGS = 2000","LBFGS = 4000", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
######## W2 = 5 ########

# %%
####### continuity and energy Eq. with Landa_u n=1 , ep=0.01 ###########
####### Momentum coefficient n=4 , ep2=0.001 ##########
####### with skip connection ###########
######## Compare Adam ########
######## W2 = 5 ########

fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1),sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

Adam_8000= np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/compareAdam/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_w2=5_skipConnection_ep=0.01.txt")
Adam_10000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/compareAdam/result_Tanh_sobol_float64_Adam=10000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=5_ep=0.01.txt")

axs[0].plot(x, Adam_8000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, Adam_10000[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["Adam = 8000","Adam = 10000", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, Adam_8000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, Adam_10000[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["Adam = 8000","Adam = 10000", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, Adam_8000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, Adam_10000[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["Adam = 8000","Adam = 10000", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
####### continuity and energy Eq. with Landa_u n=1 , ep=0.1 ###########
####### Momentum coefficient n=4 , ep2=0.001 ##########
####### with skip connection ###########
######## Compare LBFGS ########
######## W2 = 5 ########

fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1), sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

ep_landa_0_1_LBFGS_2000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/result_Tanh_sobol_float64_Adam=10000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=5_ep=0.1.txt")
ep_landa_0_1_LBFGS_4000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/result_Tanh_sobol_float64_Adam=10000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=4000_layers=12_Neurons=20_skipConnection_w2=5_ep=0.1.txt")
ep_landa_0_1_LBFGS_6000 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/result_Tanh_sobol_float64_Adam=10000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=6000_layers=12_Neurons=20_skipConnection_w2=5_ep=0.1.txt")

axs[0].plot(x, ep_landa_0_1_LBFGS_2000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, ep_landa_0_1_LBFGS_4000[19900:20000,0], linewidth=2.0)
axs[0].plot(x, ep_landa_0_1_LBFGS_6000[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["LBFGS=2000","LBFGS=4000","LBFGS=6000", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, ep_landa_0_1_LBFGS_2000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, ep_landa_0_1_LBFGS_4000[19900:20000,1], linewidth=2.0)
axs[1].plot(x, ep_landa_0_1_LBFGS_6000[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["LBFGS=2000","LBFGS=4000","LBFGS=6000", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, ep_landa_0_1_LBFGS_2000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, ep_landa_0_1_LBFGS_4000[19900:20000,2], linewidth=2.0)
axs[2].plot(x, ep_landa_0_1_LBFGS_6000[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["LBFGS=2000","LBFGS=4000","LBFGS=6000", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]

# %%
####### continuity and energy Eq. with Landa_u n=1, diff ep ###########
####### Momentum coefficient n=4 , ep2=0.001 ##########
####### with skip connection  ###########
######## Compare epsilon Landa ########
######## W2 = 5 ########


fig, axs = plt.subplots(1,3, subplot_kw=dict(box_aspect=1),sharex=True, sharey=True, layout="constrained")
# fig.suptitle('LBFGS_It')
plt.rcParams['figure.figsize'] = [15, 10]

ep_landa_0_001 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/Compare_ep_landa/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=5_ep=0.001.txt")
ep_landa_0_01 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/Compare_ep_landa/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_w2=5_skipConnection_ep=0.01.txt")
ep_landa_0_1 = np.loadtxt("Implementation/Reimann_1D_Sod/CompareParameters/energy_continiuty_withLanda_u/Compare_w2/w2=5/Compare_ep_landa/result_Tanh_sobol_float64_Adam=8000_momentum=landa_u**4_continuty_and_energy=Landa_u_LBFGS=2000_layers=12_Neurons=20_skipConnection_w2=5.txt")

axs[0].plot(x, ep_landa_0_001[19900:20000,0], linewidth=2.0)
axs[0].plot(x, ep_landa_0_01[19900:20000,0], linewidth=2.0)
axs[0].plot(x, ep_landa_0_1[19900:20000,0], linewidth=2.0)
axs[0].plot(X_density, Y_density, linewidth=2.0)
axs[0].legend(["ep=0.001","ep=0.01","ep=0.1", "Article"], fontsize="10", loc ="upper right")
axs[0].set(xlabel='x', ylabel='Density')

axs[1].plot(x, ep_landa_0_001[19900:20000,1], linewidth=2.0)
axs[1].plot(x, ep_landa_0_01[19900:20000,1], linewidth=2.0)
axs[1].plot(x, ep_landa_0_1[19900:20000,1], linewidth=2.0)
axs[1].plot(X_velocity, Y_velocity, linewidth=2.0)
axs[1].legend(["ep=0.001","ep=0.01","ep=0.1", "Article"], fontsize="10", loc ="upper left")
axs[1].set(xlabel='x', ylabel='velocity')

axs[2].plot(x, ep_landa_0_001[19900:20000,2], linewidth=2.0)
axs[2].plot(x, ep_landa_0_01[19900:20000,2], linewidth=2.0)
axs[2].plot(x, ep_landa_0_1[19900:20000,2], linewidth=2.0)
axs[2].plot(X_pressure, Y_pressure, linewidth=2.0)
axs[2].legend(["ep=0.001","ep=0.01","ep=0.1", "Article"], fontsize="10", loc ="upper right")
axs[2].set(xlabel='x', ylabel='pressure')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'pressure')]
